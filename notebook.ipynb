# %%
# Imports for !huggingface-cli login
from huggingface_hub import HfApi, Repository, login, create_repo, upload_file

# !huggingface-cli login
# Out:
# ^C
